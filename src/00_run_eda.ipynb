# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from config import FIGURES_PATH

# %%
# read in data
unit_sales = pd.read_csv("../data/sales_train_evaluation.csv")
unit_sales.head()
# Out:
#                               id        item_id    dept_id   cat_id store_id  \
# 0  HOBBIES_1_001_CA_1_evaluation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
# 1  HOBBIES_1_002_CA_1_evaluation  HOBBIES_1_002  HOBBIES_1  HOBBIES     CA_1
# 2  HOBBIES_1_003_CA_1_evaluation  HOBBIES_1_003  HOBBIES_1  HOBBIES     CA_1
# 3  HOBBIES_1_004_CA_1_evaluation  HOBBIES_1_004  HOBBIES_1  HOBBIES     CA_1
# 4  HOBBIES_1_005_CA_1_evaluation  HOBBIES_1_005  HOBBIES_1  HOBBIES     CA_1
#
#   state_id  d_1  d_2  d_3  d_4  ...  d_1932  d_1933  d_1934  d_1935  d_1936  \
# 0       CA    0    0    0    0  ...       2       4       0       0       0
# 1       CA    0    0    0    0  ...       0       1       2       1       1
# 2       CA    0    0    0    0  ...       1       0       2       0       0
# 3       CA    0    0    0    0  ...       1       1       0       4       0
# 4       CA    0    0    0    0  ...       0       0       0       2       1
#
#    d_1937  d_1938  d_1939  d_1940  d_1941
# 0       0       3       3       0       1
# 1       0       0       0       0       0
# 2       0       2       3       0       1
# 3       1       3       0       2       6
# 4       0       0       2       1       0
#
# [5 rows x 1947 columns]

# %%
unit_sales.tail()
# Out:
#                                 id      item_id  dept_id cat_id store_id  \
# 30485  FOODS_3_823_WI_3_evaluation  FOODS_3_823  FOODS_3  FOODS     WI_3
# 30486  FOODS_3_824_WI_3_evaluation  FOODS_3_824  FOODS_3  FOODS     WI_3
# 30487  FOODS_3_825_WI_3_evaluation  FOODS_3_825  FOODS_3  FOODS     WI_3
# 30488  FOODS_3_826_WI_3_evaluation  FOODS_3_826  FOODS_3  FOODS     WI_3
# 30489  FOODS_3_827_WI_3_evaluation  FOODS_3_827  FOODS_3  FOODS     WI_3
#
#       state_id  d_1  d_2  d_3  d_4  ...  d_1932  d_1933  d_1934  d_1935  \
# 30485       WI    0    0    2    2  ...       1       0       3       0
# 30486       WI    0    0    0    0  ...       0       0       0       0
# 30487       WI    0    6    0    2  ...       0       0       1       2
# 30488       WI    0    0    0    0  ...       1       1       1       4
# 30489       WI    0    0    0    0  ...       1       2       0       5
#
#        d_1936  d_1937  d_1938  d_1939  d_1940  d_1941
# 30485       1       1       0       0       1       1
# 30486       0       0       1       0       1       0
# 30487       0       1       0       1       0       2
# 30488       6       0       1       1       1       0
# 30489       4       0       2       2       5       1
#
# [5 rows x 1947 columns]

# %%
prices = pd.read_csv("../data/sell_prices.csv")
prices.head()
# Out:
#   store_id        item_id  wm_yr_wk  sell_price
# 0     CA_1  HOBBIES_1_001     11325        9.58
# 1     CA_1  HOBBIES_1_001     11326        9.58
# 2     CA_1  HOBBIES_1_001     11327        8.26
# 3     CA_1  HOBBIES_1_001     11328        8.26
# 4     CA_1  HOBBIES_1_001     11329        8.26

# %%
prices.tail()
# Out:
#         store_id      item_id  wm_yr_wk  sell_price
# 6841116     WI_3  FOODS_3_827     11617         1.0
# 6841117     WI_3  FOODS_3_827     11618         1.0
# 6841118     WI_3  FOODS_3_827     11619         1.0
# 6841119     WI_3  FOODS_3_827     11620         1.0
# 6841120     WI_3  FOODS_3_827     11621         1.0

# %%
calendar = pd.read_csv("../data/calendar.csv")
calendar.head(10)
# Out:
#          date  wm_yr_wk    weekday  wday  month  year     d event_name_1  \
# 0  2011-01-29     11101   Saturday     1      1  2011   d_1          NaN
# 1  2011-01-30     11101     Sunday     2      1  2011   d_2          NaN
# 2  2011-01-31     11101     Monday     3      1  2011   d_3          NaN
# 3  2011-02-01     11101    Tuesday     4      2  2011   d_4          NaN
# 4  2011-02-02     11101  Wednesday     5      2  2011   d_5          NaN
# 5  2011-02-03     11101   Thursday     6      2  2011   d_6          NaN
# 6  2011-02-04     11101     Friday     7      2  2011   d_7          NaN
# 7  2011-02-05     11102   Saturday     1      2  2011   d_8          NaN
# 8  2011-02-06     11102     Sunday     2      2  2011   d_9    SuperBowl
# 9  2011-02-07     11102     Monday     3      2  2011  d_10          NaN
#
#   event_type_1 event_name_2 event_type_2  snap_CA  snap_TX  snap_WI
# 0          NaN          NaN          NaN        0        0        0
# 1          NaN          NaN          NaN        0        0        0
# 2          NaN          NaN          NaN        0        0        0
# 3          NaN          NaN          NaN        1        1        0
# 4          NaN          NaN          NaN        1        0        1
# 5          NaN          NaN          NaN        1        1        1
# 6          NaN          NaN          NaN        1        0        0
# 7          NaN          NaN          NaN        1        1        1
# 8     Sporting          NaN          NaN        1        1        1
# 9          NaN          NaN          NaN        1        1        0

# %%
calendar.tail()
# Out:
#             date  wm_yr_wk    weekday  wday  month  year       d  \
# 1964  2016-06-15     11620  Wednesday     5      6  2016  d_1965
# 1965  2016-06-16     11620   Thursday     6      6  2016  d_1966
# 1966  2016-06-17     11620     Friday     7      6  2016  d_1967
# 1967  2016-06-18     11621   Saturday     1      6  2016  d_1968
# 1968  2016-06-19     11621     Sunday     2      6  2016  d_1969
#
#       event_name_1 event_type_1  event_name_2 event_type_2  snap_CA  snap_TX  \
# 1964           NaN          NaN           NaN          NaN        0        1
# 1965           NaN          NaN           NaN          NaN        0        0
# 1966           NaN          NaN           NaN          NaN        0        0
# 1967           NaN          NaN           NaN          NaN        0        0
# 1968  NBAFinalsEnd     Sporting  Father's day     Cultural        0        0
#
#       snap_WI
# 1964        1
# 1965        0
# 1966        0
# 1967        0
# 1968        0

# %% [markdown]
# EDA Checklist (from Robert Peng's Exploratory Data Analysis with R)
# 1. Formulate your question
# 2. Read in your data DONE
# 3. Check the packaging DONE
# 4. Run str() DONE
# 5. Look at the top and bottom of your data DONE
# 6. Check your "n"s DONE
# 7. Validate with atleast one external data source
# 8. Try the easy solution first
# 9. Challenge your solution
# 10. Follow-up

# %%
print(f"Shape of unit sales table: {unit_sales.shape}")
print(f"Shape of prices table: {prices.shape}")
print(f"Shape of calendar table: {calendar.shape}")
# Out:
# Shape of unit sales table: (30490, 1947)
# Shape of prices table: (6841121, 4)
# Shape of calendar table: (1969, 14)

# %% [markdown]
# Check wm_yr_wk ID

# %%
calendar_2011 = calendar.loc[calendar.year == 2011]
print(f"Range of wm_yr_wk for 2011: {calendar_2011.wm_yr_wk.min()} to {calendar_2011.wm_yr_wk.max()}")
# Out:
# Range of wm_yr_wk for 2011: 11101 to 11149

# %%
calendar_1112 = calendar.loc[(calendar["wm_yr_wk"] == 11149) | (calendar["wm_yr_wk"] == 11201)]
calendar_1112.head(14)
# Out:
#            date  wm_yr_wk    weekday  wday  month  year      d event_name_1  \
# 336  2011-12-31     11149   Saturday     1     12  2011  d_337          NaN
# 337  2012-01-01     11149     Sunday     2      1  2012  d_338      NewYear
# 338  2012-01-02     11149     Monday     3      1  2012  d_339          NaN
# 339  2012-01-03     11149    Tuesday     4      1  2012  d_340          NaN
# 340  2012-01-04     11149  Wednesday     5      1  2012  d_341          NaN
# 341  2012-01-05     11149   Thursday     6      1  2012  d_342          NaN
# 342  2012-01-06     11149     Friday     7      1  2012  d_343          NaN
# 364  2012-01-28     11201   Saturday     1      1  2012  d_365          NaN
# 365  2012-01-29     11201     Sunday     2      1  2012  d_366          NaN
# 366  2012-01-30     11201     Monday     3      1  2012  d_367          NaN
# 367  2012-01-31     11201    Tuesday     4      1  2012  d_368          NaN
# 368  2012-02-01     11201  Wednesday     5      2  2012  d_369          NaN
# 369  2012-02-02     11201   Thursday     6      2  2012  d_370          NaN
# 370  2012-02-03     11201     Friday     7      2  2012  d_371          NaN
#
#     event_type_1 event_name_2 event_type_2  snap_CA  snap_TX  snap_WI
# 336          NaN          NaN          NaN        0        0        0
# 337     National          NaN          NaN        1        1        0
# 338          NaN          NaN          NaN        1        0        1
# 339          NaN          NaN          NaN        1        1        1
# 340          NaN          NaN          NaN        1        0        0
# 341          NaN          NaN          NaN        1        1        1
# 342          NaN          NaN          NaN        1        1        1
# 364          NaN          NaN          NaN        0        0        0
# 365          NaN          NaN          NaN        0        0        0
# 366          NaN          NaN          NaN        0        0        0
# 367          NaN          NaN          NaN        0        0        0
# 368          NaN          NaN          NaN        1        1        0
# 369          NaN          NaN          NaN        1        0        1
# 370          NaN          NaN          NaN        1        1        1

# %%
calendar.iloc[336:350,:]
# Out:
#            date  wm_yr_wk    weekday  wday  month  year      d  \
# 336  2011-12-31     11149   Saturday     1     12  2011  d_337
# 337  2012-01-01     11149     Sunday     2      1  2012  d_338
# 338  2012-01-02     11149     Monday     3      1  2012  d_339
# 339  2012-01-03     11149    Tuesday     4      1  2012  d_340
# 340  2012-01-04     11149  Wednesday     5      1  2012  d_341
# 341  2012-01-05     11149   Thursday     6      1  2012  d_342
# 342  2012-01-06     11149     Friday     7      1  2012  d_343
# 343  2012-01-07     11150   Saturday     1      1  2012  d_344
# 344  2012-01-08     11150     Sunday     2      1  2012  d_345
# 345  2012-01-09     11150     Monday     3      1  2012  d_346
# 346  2012-01-10     11150    Tuesday     4      1  2012  d_347
# 347  2012-01-11     11150  Wednesday     5      1  2012  d_348
# 348  2012-01-12     11150   Thursday     6      1  2012  d_349
# 349  2012-01-13     11150     Friday     7      1  2012  d_350
#
#           event_name_1 event_type_1 event_name_2 event_type_2  snap_CA  \
# 336                NaN          NaN          NaN          NaN        0
# 337            NewYear     National          NaN          NaN        1
# 338                NaN          NaN          NaN          NaN        1
# 339                NaN          NaN          NaN          NaN        1
# 340                NaN          NaN          NaN          NaN        1
# 341                NaN          NaN          NaN          NaN        1
# 342                NaN          NaN          NaN          NaN        1
# 343  OrthodoxChristmas    Religious          NaN          NaN        1
# 344                NaN          NaN          NaN          NaN        1
# 345                NaN          NaN          NaN          NaN        1
# 346                NaN          NaN          NaN          NaN        1
# 347                NaN          NaN          NaN          NaN        0
# 348                NaN          NaN          NaN          NaN        0
# 349                NaN          NaN          NaN          NaN        0
#
#      snap_TX  snap_WI
# 336        0        0
# 337        1        0
# 338        0        1
# 339        1        1
# 340        0        0
# 341        1        1
# 342        1        1
# 343        1        0
# 344        0        1
# 345        1        1
# 346        0        0
# 347        1        1
# 348        1        1
# 349        1        0

# %% [markdown]
# 4. Run str()

# %%
unit_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30490 entries, 0 to 30489
# Columns: 1947 entries, id to d_1941
# dtypes: int64(1941), object(6)
# memory usage: 452.9+ MB

# %%
prices.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6841121 entries, 0 to 6841120
# Data columns (total 4 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   store_id    object
#  1   item_id     object
#  2   wm_yr_wk    int64
#  3   sell_price  float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 208.8+ MB

# %%
calendar.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1969 entries, 0 to 1968
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          1969 non-null   object
#  1   wm_yr_wk      1969 non-null   int64
#  2   weekday       1969 non-null   object
#  3   wday          1969 non-null   int64
#  4   month         1969 non-null   int64
#  5   year          1969 non-null   int64
#  6   d             1969 non-null   object
#  7   event_name_1  162 non-null    object
#  8   event_type_1  162 non-null    object
#  9   event_name_2  5 non-null      object
#  10  event_type_2  5 non-null      object
#  11  snap_CA       1969 non-null   int64
#  12  snap_TX       1969 non-null   int64
#  13  snap_WI       1969 non-null   int64
# dtypes: int64(7), object(7)
# memory usage: 215.5+ KB

# %%
calendar.groupby(by=["year"]).count()
# Out:
#       date  wm_yr_wk  weekday  wday  month    d  event_name_1  event_type_1  \
# year
# 2011   337       337      337   337    337  337            26            26
# 2012   366       366      366   366    366  366            30            30
# 2013   365       365      365   365    365  365            29            29
# 2014   365       365      365   365    365  365            28            28
# 2015   365       365      365   365    365  365            30            30
# 2016   171       171      171   171    171  171            19            19
#
#       event_name_2  event_type_2  snap_CA  snap_TX  snap_WI
# year
# 2011             1             1      337      337      337
# 2012             0             0      366      366      366
# 2013             1             1      365      365      365
# 2014             2             2      365      365      365
# 2015             0             0      365      365      365
# 2016             1             1      171      171      171

# %%
print((calendar["wm_yr_wk"].min(),calendar["wm_yr_wk"].max()))
print((prices["wm_yr_wk"].min(),prices["wm_yr_wk"].max()))
# Out:
# (np.int64(11101), np.int64(11621))
# (np.int64(11101), np.int64(11621))

# %%
products = prices["item_id"].unique()

print(f"There are {products.shape[0]} different products.")

np.random.seed(2001)
products_sample = products[np.random.randint(0,products.shape[0],size=10)]
products_sample
# Out:
# There are 3049 different products.
# array(['HOUSEHOLD_2_445', 'FOODS_3_214', 'FOODS_2_238', 'FOODS_3_522',
#        'HOUSEHOLD_1_443', 'FOODS_1_027', 'FOODS_1_135', 'FOODS_3_593',
#        'FOODS_3_464', 'HOBBIES_1_043'], dtype=object)

# %%
plot_df = prices.loc[prices["item_id"].isin(products_sample)]

plt.figure(figsize=(13,10))
sns.lineplot(data=plot_df,
             x="wm_yr_wk",
             y="sell_price",
             hue="item_id",
             errorbar=None)
plt.xlabel("week ID")
plt.ylabel("Unit Sell Price (USD)")
plt.title("The variability of prices over the time horizon is sufficient.")
plt.show()

# %%
standard_deviations = prices[["item_id","sell_price"]].groupby(by="item_id").std().reset_index()

# %%
standard_deviations
# Out:
#               item_id  sell_price
# 0         FOODS_1_001    0.116225
# 1         FOODS_1_002    0.485684
# 2         FOODS_1_003    0.156082
# 3         FOODS_1_004    0.106627
# 4         FOODS_1_005    0.196211
# ...               ...         ...
# 3044  HOUSEHOLD_2_512    0.026996
# 3045  HOUSEHOLD_2_513    0.000000
# 3046  HOUSEHOLD_2_514    0.916503
# 3047  HOUSEHOLD_2_515    0.027617
# 3048  HOUSEHOLD_2_516    0.114942
#
# [3049 rows x 2 columns]

# %%
standard_deviations["category"] = standard_deviations["item_id"].str.extract(r'(HOUSEHOLD|FOODS|HOBBIES)')
standard_deviations.groupby('category').median(numeric_only=True).reset_index()
# Out:
#     category  sell_price
# 0      FOODS    0.126944
# 1    HOBBIES    0.100428
# 2  HOUSEHOLD    0.125474

# %% [markdown]
# Is there a trivial pattern in food stamp days?

# %%
calendar["date"] = pd.to_datetime(calendar["date"],format="%Y-%m-%d")
calendar["day"] = calendar.date.dt.day

# %%
snap_tx_df = calendar.groupby(by=["month","day"])["snap_TX"].sum().reset_index()
plot_df = snap_tx_df.pivot(index="month", columns="day", values="snap_TX")

# to plot SNAP days, a heatmap is used
sns.heatmap(plot_df, cmap=sns.cubehelix_palette(as_cmap=True))
# TODO: use relative paths
plt.savefig(FIGURES_PATH + "snap_pattern.pdf", format="pdf", bbox_inches="tight")

# %% [markdown]
# Do SNAP-eligible days induce higher demand?

# %%
STATE = "TX"

snap_days_wi = calendar.loc[calendar[f"snap_{STATE}"] == 1,"d"].values
snap_wi_sales = unit_sales.loc[unit_sales.state_id ==STATE, [col for col in unit_sales.columns if (col in snap_days_wi)]]
nonsnap_wi_sales = unit_sales.loc[unit_sales.state_id ==STATE, [col for col in unit_sales.columns if ((col not in snap_days_wi) and col.startswith("d_"))]]
print(f"The average demand on SNAP-eligible days in {STATE} is {np.mean(snap_wi_sales.sum(axis=0)):.2f}.")
print(f"The average demand on non SNAP-eligible days in {STATE} is {np.mean(nonsnap_wi_sales.sum(axis=0)):.2f}.")
# Out:
# The average demand on SNAP-eligible days in TX is 10643.51.
# The average demand on non SNAP-eligible days in TX is 9543.86.

# %% [markdown]
# ## Plot the demand-price curve to test the validity of linear assumption
#
# For FOODS product category the negative linear relationship between price and quantity does not hold when we consider the total time horizon. Neither on department-level for a shorter time horizon: prices were found to be fixed on a 1Y time horizon for foods departments (sub-categories). The negative price-demand relationship does not hold for products with the longest history, rather the avg. weekly prices were stable and state-dependent.

# %% [markdown]
# **TL; DR: Choosing the 3 foods products that have the most price points over the history yields negative demand-price relationships in a given state.**

# %%
unique_prices = (
    prices[prices["item_id"].str.startswith("FOODS")]
    .groupby(["store_id", "item_id"])["sell_price"]
    .nunique()
    .rename("n_unique_prices")
    .reset_index()
    .sort_values("n_unique_prices", ascending=False)
)

unique_prices.head(50)
# Out:
#       store_id      item_id  n_unique_prices
# 5841      TX_1  FOODS_1_095               21
# 8715      TX_3  FOODS_1_095               21
# 10185     WI_1  FOODS_1_129               20
# 93        CA_1  FOODS_1_095               18
# 4404      CA_4  FOODS_1_095               18
# 1530      CA_2  FOODS_1_095               18
# 7278      TX_2  FOODS_1_095               18
# 13059     WI_3  FOODS_1_129               18
# 11622     WI_2  FOODS_1_129               18
# 8716      TX_3  FOODS_1_096               17
# 10133     WI_1  FOODS_1_076               17
# 11590     WI_2  FOODS_1_096               17
# 5874      TX_1  FOODS_1_129               17
# 13027     WI_3  FOODS_1_096               17
# 5842      TX_1  FOODS_1_096               17
# 10153     WI_1  FOODS_1_096               17
# 8748      TX_3  FOODS_1_129               16
# 11528     WI_2  FOODS_1_034               16
# 2967      CA_3  FOODS_1_095               16
# 11547     WI_2  FOODS_1_053               16
# 12965     WI_3  FOODS_1_034               16
# 7279      TX_2  FOODS_1_096               16
# 13007     WI_3  FOODS_1_076               16
# 3000      CA_3  FOODS_1_129               16
# 1531      CA_2  FOODS_1_096               16
# 7311      TX_2  FOODS_1_129               16
# 11570     WI_2  FOODS_1_076               16
# 2968      CA_3  FOODS_1_096               15
# 10091     WI_1  FOODS_1_034               15
# 4405      CA_4  FOODS_1_096               15
# 126       CA_1  FOODS_1_129               15
# 6071      TX_1  FOODS_2_109               15
# 10110     WI_1  FOODS_1_053               15
# 10152     WI_1  FOODS_1_095               14
# 7425      TX_2  FOODS_2_025               14
# 12984     WI_3  FOODS_1_053               14
# 94        CA_1  FOODS_1_096               14
# 4437      CA_4  FOODS_1_129               14
# 8718      TX_3  FOODS_1_098               14
# 2978      CA_3  FOODS_1_107               14
# 11589     WI_2  FOODS_1_095               14
# 3405      CA_3  FOODS_2_317               14
# 2956      CA_3  FOODS_1_084               14
# 13029     WI_3  FOODS_1_098               14
# 11600     WI_2  FOODS_1_107               14
# 10155     WI_1  FOODS_1_098               14
# 8630      TX_3  FOODS_1_010               14
# 10163     WI_1  FOODS_1_107               13
# 10225     WI_1  FOODS_1_170               13
# 8632      TX_3  FOODS_1_012               13

# %%
# get product-level demand for FOODS per day
# from EDA, the prices were founds to be state-dependent
foods_demand = unit_sales[unit_sales.state_id == "TX"]
foods_demand = foods_demand.loc[foods_demand.cat_id == 'FOODS',["item_id"] + [col for col in foods_demand.columns if col.startswith("d_")]]
q = foods_demand.groupby(by=["item_id"]).mean().reset_index()

# %%
product_list = ["FOODS_1_096","FOODS_1_129"]

# %%
q = q[q.item_id.isin(product_list)]

# %%
merged_df = calendar.merge(prices, how="left", on="wm_yr_wk")
merged_df = merged_df[merged_df.item_id.isin(product_list)]

# %%
p = (
    merged_df
    .groupby(by=["item_id", "d"])["sell_price"]
    .mean()
    .reset_index()
    .assign(d_num=lambda df: df["d"].str.extract(r'(\d+)').astype(int))
    .sort_values(["item_id", "d_num"])
    .drop(columns="d_num")
)

# %%
q_long = q.reset_index().melt(id_vars="item_id", var_name="d", value_name="quantity")
q_long.head()
# Out:
#        item_id      d    quantity
# 0  FOODS_1_096  index   94.000000
# 1  FOODS_1_129  index  126.000000
# 2  FOODS_1_096    d_1    2.333333
# 3  FOODS_1_129    d_1    6.333333
# 4  FOODS_1_096    d_2    2.666667

# %%
pq = p.merge(q_long,how="left", on=["d","item_id"])
pq = pq.dropna()

# %% [markdown]
# Optionally restrict the analysis to the last x weeks. In the final plot this was not done as in the AIDS paper of Deaton et al. (1980) time series data is used to estimate the demand equations.

# %%
# day_num = pq["d"].str.extract(r"d_(\d+)").astype(int)[0]
# max_day = day_num.max()

# pq = pq[day_num > max_day - 52]

# %%
prices_demand = pq.drop(columns=["d"], inplace=False).groupby(by=["item_id","sell_price"]).mean().reset_index()

# %%
sns.scatterplot(data=prices_demand, x="sell_price", y="quantity", hue="item_id")
plt.xlabel("Sell Price (USD)")
plt.ylabel("Sold Quantity")
# plt.title("Negative price-demand relationship holds for most active products")
plt.savefig(FIGURES_PATH + "pq_pattern.pdf", format="pdf", bbox_inches="tight")

# %% [markdown]
# With a given price granularity, all actions (prices) could have non-zero share, therefore the assumption behind Offline RL could be satisfied.

# %% [markdown]
# # Exploratory Analysis of Online Retail II Dataset (UCI)

# %%
# read in data
online_retail = pd.read_excel("../data/online_retail_ii/online_retail_II.xlsx")

# %%
# run .info() (pandas equivalent of str)
online_retail.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 525461 entries, 0 to 525460
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Invoice      525461 non-null  object
#  1   StockCode    525461 non-null  object
#  2   Description  522533 non-null  object
#  3   Quantity     525461 non-null  int64
#  4   InvoiceDate  525461 non-null  datetime64[ns]
#  5   Price        525461 non-null  float64
#  6   Customer ID  417534 non-null  float64
#  7   Country      525461 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 32.1+ MB

# %%
# look at top and bottom of data
online_retail.head()
# Out:
#   Invoice StockCode                          Description  Quantity  \
# 0  489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1  489434    79323P                   PINK CHERRY LIGHTS        12
# 2  489434    79323W                  WHITE CHERRY LIGHTS        12
# 3  489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4  489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
#
#           InvoiceDate  Price  Customer ID         Country
# 0 2009-12-01 07:45:00   6.95      13085.0  United Kingdom
# 1 2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 2 2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 3 2009-12-01 07:45:00   2.10      13085.0  United Kingdom
# 4 2009-12-01 07:45:00   1.25      13085.0  United Kingdom

# %%
online_retail.tail()
# Out:
#        Invoice StockCode                         Description  Quantity  \
# 525456  538171     22271                FELTCRAFT DOLL ROSIE         2
# 525457  538171     22750        FELTCRAFT PRINCESS LOLA DOLL         1
# 525458  538171     22751      FELTCRAFT PRINCESS OLIVIA DOLL         1
# 525459  538171     20970  PINK FLORAL FELTCRAFT SHOULDER BAG         2
# 525460  538171     21931              JUMBO STORAGE BAG SUKI         2
#
#                InvoiceDate  Price  Customer ID         Country
# 525456 2010-12-09 20:01:00   2.95      17530.0  United Kingdom
# 525457 2010-12-09 20:01:00   3.75      17530.0  United Kingdom
# 525458 2010-12-09 20:01:00   3.75      17530.0  United Kingdom
# 525459 2010-12-09 20:01:00   3.75      17530.0  United Kingdom
# 525460 2010-12-09 20:01:00   1.95      17530.0  United Kingdom

# %%
# check the packaging
print(f"The shape of the online retail II dataset is {online_retail.shape}")
# Out:
# The shape of the online retail II dataset is (525461, 8)

# %%
# check your n-s
print(f"Number of unique invoices:{online_retail["Invoice"].unique().shape[0]}")
print(f"Number of unique countries:{online_retail["Country"].unique().shape[0]}")
print(f"Number of unique products:{online_retail["StockCode"].unique().shape[0]}")
# Out:
# Number of unique invoices:28816
# Number of unique countries:40
# Number of unique products:4632

# %%
print(f"Date range available: {online_retail["InvoiceDate"].min()} to {online_retail["InvoiceDate"].max()}")
# Out:
# Date range available: 2009-12-01 07:45:00 to 2010-12-09 20:01:00

# %%
online_retail.groupby(by=["StockCode"]).count().iloc[:,0]
# Out:
# StockCode
# 10002           327
# 10080             7
# 10109             2
# 10120            49
# 10125            87
#                ...
# gift_0001_60      2
# gift_0001_70      3
# gift_0001_80      4
# gift_0001_90      2
# m                 4
# Name: Invoice, Length: 4632, dtype: int64

# %%
product_counts = online_retail.groupby(by=["StockCode"]).count().iloc[:,0]
available_prod_hist = product_counts.value_counts()

# %%
sns.barplot(x=available_prod_hist.index[:30], y=available_prod_hist[:30])
plt.title("From the 4632 products the majority has several transactions.")
plt.xlabel("# of available transactions")
plt.show()

# %%
num_above_30 = product_counts[product_counts>30].shape[0]
print(f"Number of products with atleast 30 transactions: {num_above_30}")
# Out:
# Number of products with atleast 30 transactions: 2592

# %%
prod_above_30 = product_counts[product_counts>30].index
prod_above_30
# Out:
# Index([         10002,          10120,          10125,          10133,
#                 10134,          10135,          11001,          15034,
#                 15036,          15039,
#        ...
#              '90214S',       'ADJUST', 'BANK CHARGES',           'C2',
#                   'D',     'DCGS0058',          'DOT',            'M',
#                'POST',            'S'],
#       dtype='object', name='StockCode', length=2592)

# %%
chosen_products = list(pd.Series(prod_above_30).sample(10))

# %%
plot_df = online_retail.loc[online_retail["StockCode"].isin(chosen_products),["StockCode","Price"]]

# %%
plot_df
# Out:
#        StockCode  Price
# 525        48194   6.75
# 871        48194   6.75
# 877        20969   3.75
# 1037       48194   6.75
# 1443       84813  12.75
# ...          ...    ...
# 524705     48194   7.95
# 524894     20969   7.62
# 525011     20969   7.62
# 525331     22735   1.65
# 525394     22943   4.95
#
# [2457 rows x 2 columns]

# %%
g = sns.catplot(data=plot_df, x="StockCode", y="Price",kind='swarm')

for ax in g.axes.flat:
    ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha="right")
plt.title("For a chosen set of products, several price points are available.")
plt.show()
# Out:
# c:\Users\Kim Levente\AppData\Local\Programs\Python\Python313\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 96.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\Kim Levente\AppData\Local\Programs\Python\Python313\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 85.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\Kim Levente\AppData\Local\Programs\Python\Python313\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 92.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\Kim Levente\AppData\Local\Programs\Python\Python313\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 96.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\Kim Levente\AppData\Local\Programs\Python\Python313\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 94.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\Kim Levente\AppData\Local\Programs\Python\Python313\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 83.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\Kim Levente\AppData\Local\Programs\Python\Python313\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 87.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\Kim Levente\AppData\Local\Programs\Python\Python313\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 90.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\Kim Levente\AppData\Local\Programs\Python\Python313\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 94.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\Kim Levente\AppData\Local\Programs\Python\Python313\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 68.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\Kim Levente\AppData\Local\Programs\Python\Python313\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 96.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\Kim Levente\AppData\Local\Temp\ipykernel_15092\3416095540.py:4: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha="right")
# c:\Users\Kim Levente\AppData\Local\Programs\Python\Python313\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 96.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\Kim Levente\AppData\Local\Programs\Python\Python313\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 85.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\Kim Levente\AppData\Local\Programs\Python\Python313\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 92.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\Kim Levente\AppData\Local\Programs\Python\Python313\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 96.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\Kim Levente\AppData\Local\Programs\Python\Python313\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 94.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\Kim Levente\AppData\Local\Programs\Python\Python313\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 83.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\Kim Levente\AppData\Local\Programs\Python\Python313\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 87.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\Kim Levente\AppData\Local\Programs\Python\Python313\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 90.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\Kim Levente\AppData\Local\Programs\Python\Python313\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 94.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\Kim Levente\AppData\Local\Programs\Python\Python313\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 68.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
